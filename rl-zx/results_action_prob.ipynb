# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import json
import seaborn as sns
import os

# %%
path = os.path.join('results', '5x60_non_clifford', 'data', 'action_dist')
path_fig = os.path.join('results', '5x60_non_clifford', 'figures', 'action_dist')

results = {}
keys = [
    "action_dist",
    "episode_len",
    "opt_episode_len",
    "diff_episode_len"
]
for key in keys:
    results = {}
    with open(os.path.join(path,"opt_episode_len_probs10x520.json")) as f:
        pyzx_stats_p = json.load(f)
        f.close()
        results["action_dist"] = pyzx_stats_p["action_dist"]
        results["episode_len"] = pyzx_stats_p["episode_len"]
        results["opt_episode_len"] = pyzx_stats_p["opt_episode_len"]
        results["diff_episode_len"] = pyzx_stats_p["diff_episode_len"]

# %%
results["action_dist"][0]
results["diff_episode_len"]
# Out:
# [-11,
#  -38,
#  -52,
#  -17,
#  -59,
#  -28,
#  -3,
#  -13,
#  -37,
#  -8,
#  -13,
#  -65,
#  -25,
#  -82,
#  -18,
#  -8,
#  -53,
#  -9,
#  -10,
#  -37,
#  -54,
#  -19,
#  -107,
#  -7,
#  -45,
#  -22,
#  0,
#  -57,
#  0,
#  -83,
#  -17,
#  -27,
#  -44,
#  -110,
#  -2,
#  -7,
#  -29,
#  -47,
#  -29,
#  -73,
#  -94,
#  -27,
#  -18,
#  -10,
#  -20,
#  -9,
#  -16,
#  -53,
#  -24,
#  -7,
#  -61,
#  -14,
#  -107,
#  -69,
#  -5,
#  -69,
#  -43,
#  -44,
#  -10,
#  -118,
#  -28,
#  -21,
#  -28,
#  -21,
#  -5,
#  -15,
#  -21,
#  0,
#  -53,
#  -91,
#  -8,
#  -69,
#  -24,
#  -36,
#  -2,
#  -24,
#  0,
#  -56,
#  -89,
#  -30,
#  -26,
#  -10,
#  -61,
#  -114,
#  0,
#  -32,
#  -11,
#  -30,
#  0,
#  -42,
#  -23,
#  -14,
#  -5,
#  -7,
#  -33,
#  -2,
#  -17,
#  -90,
#  -70,
#  -28]
